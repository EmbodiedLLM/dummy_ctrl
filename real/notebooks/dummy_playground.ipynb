# %%
import sys
sys.path.append('..')
import fibre
import numpy as np

from __future__ import print_function
logger = fibre.utils.Logger(verbose=True)

# %% [markdown]
# ## 机械臂的SN码可以通过`lsusb`命令查看

# %%
teach_arm = fibre.find_any(serial_number="3950366E3233", logger=logger)
# Out:
# ConfigurationValue 1
# 	InterfaceNumber 0,0
# 		EndpointAddress 130
# 	InterfaceNumber 1,0
# 		EndpointAddress 1
# 		EndpointAddress 129
# 	InterfaceNumber 2,0
# 		EndpointAddress 3
# 		EndpointAddress 131
# Kernel Driver was not attached
# EndpointAddress for writing 3
# EndpointAddress for reading 131
# Connecting to device on USB device bus 1 device 5
# Device reported JSON version ID: 2015063666
# JSON: [
# {'name': '', 'id': 0, 'type': 'json', 'access': 'r'},
# {'name': 'serial_number', 'id': 1, 'type': 'uint64', 'access': 'r'},
# {'name': 'get_temperature', 'id': 2, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 3, 'type': 'float', 'access': 'rw'}]},
# {'name': 'get_voltage', 'id': 4, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 5, 'type': 'float', 'access': 'rw'}]},
# {'name': 'robot', 'type': 'object', 'members': [
# {'name': 'calibrate_home_offset', 'id': 6, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'homing', 'id': 7, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'resting', 'id': 8, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'joint_1', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 9, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 10, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 11, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 12, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 13, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 14, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 15, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 16, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 17, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 18, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 19, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 20, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 21, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 22, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 23, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 24, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 25, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 26, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 27, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 28, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 29, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_2', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 30, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 31, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 32, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 33, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 34, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 35, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 36, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 37, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 38, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 39, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 40, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 41, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 42, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 43, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 44, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 45, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 46, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 47, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 48, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 49, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 50, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_3', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 51, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 52, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 53, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 54, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 55, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 56, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 57, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 58, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 59, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 60, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 61, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 62, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 63, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 64, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 65, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 66, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 67, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 68, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 69, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 70, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 71, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_4', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 72, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 73, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 74, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 75, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 76, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 77, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 78, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 79, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 80, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 81, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 82, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 83, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 84, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 85, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 86, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 87, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 88, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 89, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 90, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 91, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 92, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_5', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 93, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 94, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 95, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 96, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 97, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 98, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 99, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 100, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 101, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 102, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 103, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 104, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 105, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 106, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 107, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 108, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 109, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 110, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 111, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 112, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 113, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_6', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 114, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 115, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 116, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 117, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 118, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 119, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 120, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 121, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 122, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 123, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 124, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 125, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 126, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 127, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 128, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 129, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 130, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 131, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 132, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 133, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 134, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_all', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 135, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 136, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 137, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 138, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 139, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 140, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 141, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 142, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 143, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 144, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 145, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 146, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 147, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 148, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 149, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 150, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 151, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 152, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 153, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 154, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 155, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'hand', 'type': 'object', 'members': [
# {'name': 'is_enabled', 'id': 156, 'type': 'bool', 'access': 'r'},
# {'name': 'current_mode', 'id': 157, 'type': 'uint32', 'access': 'r'},
# {'name': 'position', 'id': 158, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 159, 'type': 'float', 'access': 'r'},
# {'name': 'torque', 'id': 160, 'type': 'float', 'access': 'r'},
# {'name': 'rotor_temp', 'id': 161, 'type': 'float', 'access': 'r'},
# {'name': 'is_connected', 'id': 162, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 163, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'set_enable', 'id': 164, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 165, 'type': 'bool', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 166, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'set_mode', 'id': 167, 'type': 'function', 'inputs': [
# {'name': 'mode', 'id': 168, 'type': 'uint32', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 169, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'read_mode', 'id': 170, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 171, 'type': 'uint32', 'access': 'rw'}]},
# {'name': 'set_zero', 'id': 172, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'control_mit', 'id': 173, 'type': 'function', 'inputs': [
# {'name': 'kp', 'id': 174, 'type': 'float', 'access': 'rw'},
# {'name': 'kd', 'id': 175, 'type': 'float', 'access': 'rw'},
# {'name': 'position', 'id': 176, 'type': 'float', 'access': 'rw'},
# {'name': 'velocity', 'id': 177, 'type': 'float', 'access': 'rw'},
# {'name': 'torque', 'id': 178, 'type': 'float', 'access': 'rw'}], 'outputs': []}]},
# {'name': 'reboot', 'id': 179, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 180, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 181, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'move_j', 'id': 182, 'type': 'function', 'inputs': [
# {'name': 'j1', 'id': 183, 'type': 'float', 'access': 'rw'},
# {'name': 'j2', 'id': 184, 'type': 'float', 'access': 'rw'},
# {'name': 'j3', 'id': 185, 'type': 'float', 'access': 'rw'},
# {'name': 'j4', 'id': 186, 'type': 'float', 'access': 'rw'},
# {'name': 'j5', 'id': 187, 'type': 'float', 'access': 'rw'},
# {'name': 'j6', 'id': 188, 'type': 'float', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 189, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'move_l', 'id': 190, 'type': 'function', 'inputs': [
# {'name': 'x', 'id': 191, 'type': 'float', 'access': 'rw'},
# {'name': 'y', 'id': 192, 'type': 'float', 'access': 'rw'},
# {'name': 'z', 'id': 193, 'type': 'float', 'access': 'rw'},
# {'name': 'a', 'id': 194, 'type': 'float', 'access': 'rw'},
# {'name': 'b', 'id': 195, 'type': 'float', 'access': 'rw'},
# {'name': 'c', 'id': 196, 'type': 'float', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 197, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'set_joint_speed', 'id': 198, 'type': 'function', 'inputs': [
# {'name': 'speed', 'id': 199, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_joint_acc', 'id': 200, 'type': 'function', 'inputs': [
# {'name': 'acc', 'id': 201, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_command_mode', 'id': 202, 'type': 'function', 'inputs': [
# {'name': 'mode', 'id': 203, 'type': 'uint32', 'access': 'rw'}], 'outputs': []},
# {'name': 'tuning', 'type': 'object', 'members': [
# {'name': 'set_tuning_freq_amp', 'id': 204, 'type': 'function', 'inputs': [
# {'name': 'freq', 'id': 205, 'type': 'float', 'access': 'rw'},
# {'name': 'amp', 'id': 206, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_tuning_flag', 'id': 207, 'type': 'function', 'inputs': [
# {'name': 'flag', 'id': 208, 'type': 'uint8', 'access': 'rw'}], 'outputs': []}]},
# {'name': 'eef_pose', 'type': 'object', 'members': [
# {'name': 'x', 'id': 209, 'type': 'float', 'access': 'r'},
# {'name': 'y', 'id': 210, 'type': 'float', 'access': 'r'},
# {'name': 'z', 'id': 211, 'type': 'float', 'access': 'r'},
# {'name': 'a', 'id': 212, 'type': 'float', 'access': 'r'},
# {'name': 'b', 'id': 213, 'type': 'float', 'access': 'r'},
# {'name': 'c', 'id': 214, 'type': 'float', 'access': 'r'},
# {'name': 'update_pose_6D', 'id': 215, 'type': 'function', 'inputs': [], 'outputs': []}]}]}]
# malformed member : unsupported codec json

# %%
follow_arm = fibre.find_any(serial_number="396636713233", logger=logger)
# Out:
# ConfigurationValue 1
# 	InterfaceNumber 0,0
# 		EndpointAddress 130
# 	InterfaceNumber 1,0
# 		EndpointAddress 1
# 		EndpointAddress 129
# 	InterfaceNumber 2,0
# 		EndpointAddress 3
# 		EndpointAddress 131
#
# Kernel Driver was not attached
# EndpointAddress for writing 3
# EndpointAddress for reading 131
# Connecting to device on USB device bus 1 device 1
# Device reported JSON version ID: 2015063666
# JSON: [
# {'name': '', 'id': 0, 'type': 'json', 'access': 'r'},
# {'name': 'serial_number', 'id': 1, 'type': 'uint64', 'access': 'r'},
# {'name': 'get_temperature', 'id': 2, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 3, 'type': 'float', 'access': 'rw'}]},
# {'name': 'get_voltage', 'id': 4, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 5, 'type': 'float', 'access': 'rw'}]},
# {'name': 'robot', 'type': 'object', 'members': [
# {'name': 'calibrate_home_offset', 'id': 6, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'homing', 'id': 7, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'resting', 'id': 8, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'joint_1', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 9, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 10, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 11, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 12, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 13, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 14, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 15, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 16, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 17, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 18, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 19, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 20, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 21, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 22, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 23, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 24, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 25, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 26, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 27, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 28, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 29, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_2', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 30, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 31, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 32, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 33, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 34, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 35, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 36, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 37, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 38, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 39, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 40, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 41, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 42, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 43, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 44, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 45, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 46, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 47, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 48, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 49, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 50, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_3', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 51, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 52, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 53, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 54, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 55, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 56, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 57, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 58, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 59, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 60, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 61, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 62, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 63, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 64, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 65, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 66, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 67, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 68, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 69, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 70, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 71, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_4', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 72, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 73, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 74, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 75, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 76, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 77, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 78, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 79, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 80, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 81, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 82, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 83, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 84, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 85, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 86, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 87, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 88, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 89, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 90, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 91, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 92, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_5', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 93, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 94, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 95, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 96, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 97, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 98, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 99, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 100, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 101, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 102, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 103, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 104, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 105, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 106, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 107, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 108, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 109, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 110, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 111, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 112, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 113, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_6', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 114, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 115, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 116, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 117, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 118, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 119, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 120, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 121, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 122, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 123, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 124, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 125, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 126, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 127, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 128, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 129, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 130, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 131, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 132, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 133, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 134, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'joint_all', 'type': 'object', 'members': [
# {'name': 'angle', 'id': 135, 'type': 'float', 'access': 'r'},
# {'name': 'current', 'id': 136, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 137, 'type': 'float', 'access': 'r'},
# {'name': 'reboot', 'id': 138, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'erase_configs', 'id': 139, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 140, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 141, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_position', 'id': 142, 'type': 'function', 'inputs': [
# {'name': 'pos', 'id': 143, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_velocity', 'id': 144, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 145, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'apply_home_offset', 'id': 146, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_dce_kp', 'id': 147, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 148, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kv', 'id': 149, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 150, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_ki', 'id': 151, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 152, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_dce_kd', 'id': 153, 'type': 'function', 'inputs': [
# {'name': 'vel', 'id': 154, 'type': 'int32', 'access': 'rw'}], 'outputs': []},
# {'name': 'update_angle', 'id': 155, 'type': 'function', 'inputs': [], 'outputs': []}]},
# {'name': 'hand', 'type': 'object', 'members': [
# {'name': 'is_enabled', 'id': 156, 'type': 'bool', 'access': 'r'},
# {'name': 'current_mode', 'id': 157, 'type': 'uint32', 'access': 'r'},
# {'name': 'position', 'id': 158, 'type': 'float', 'access': 'r'},
# {'name': 'velocity', 'id': 159, 'type': 'float', 'access': 'r'},
# {'name': 'torque', 'id': 160, 'type': 'float', 'access': 'r'},
# {'name': 'rotor_temp', 'id': 161, 'type': 'float', 'access': 'r'},
# {'name': 'is_connected', 'id': 162, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 163, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'set_enable', 'id': 164, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 165, 'type': 'bool', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 166, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'set_mode', 'id': 167, 'type': 'function', 'inputs': [
# {'name': 'mode', 'id': 168, 'type': 'uint32', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 169, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'read_mode', 'id': 170, 'type': 'function', 'inputs': [], 'outputs': [
# {'name': 'result', 'id': 171, 'type': 'uint32', 'access': 'rw'}]},
# {'name': 'set_zero', 'id': 172, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'control_mit', 'id': 173, 'type': 'function', 'inputs': [
# {'name': 'kp', 'id': 174, 'type': 'float', 'access': 'rw'},
# {'name': 'kd', 'id': 175, 'type': 'float', 'access': 'rw'},
# {'name': 'position', 'id': 176, 'type': 'float', 'access': 'rw'},
# {'name': 'velocity', 'id': 177, 'type': 'float', 'access': 'rw'},
# {'name': 'torque', 'id': 178, 'type': 'float', 'access': 'rw'}], 'outputs': []}]},
# {'name': 'reboot', 'id': 179, 'type': 'function', 'inputs': [], 'outputs': []},
# {'name': 'set_enable', 'id': 180, 'type': 'function', 'inputs': [
# {'name': 'enable', 'id': 181, 'type': 'bool', 'access': 'rw'}], 'outputs': []},
# {'name': 'move_j', 'id': 182, 'type': 'function', 'inputs': [
# {'name': 'j1', 'id': 183, 'type': 'float', 'access': 'rw'},
# {'name': 'j2', 'id': 184, 'type': 'float', 'access': 'rw'},
# {'name': 'j3', 'id': 185, 'type': 'float', 'access': 'rw'},
# {'name': 'j4', 'id': 186, 'type': 'float', 'access': 'rw'},
# {'name': 'j5', 'id': 187, 'type': 'float', 'access': 'rw'},
# {'name': 'j6', 'id': 188, 'type': 'float', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 189, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'move_l', 'id': 190, 'type': 'function', 'inputs': [
# {'name': 'x', 'id': 191, 'type': 'float', 'access': 'rw'},
# {'name': 'y', 'id': 192, 'type': 'float', 'access': 'rw'},
# {'name': 'z', 'id': 193, 'type': 'float', 'access': 'rw'},
# {'name': 'a', 'id': 194, 'type': 'float', 'access': 'rw'},
# {'name': 'b', 'id': 195, 'type': 'float', 'access': 'rw'},
# {'name': 'c', 'id': 196, 'type': 'float', 'access': 'rw'}], 'outputs': [
# {'name': 'result', 'id': 197, 'type': 'bool', 'access': 'rw'}]},
# {'name': 'set_joint_speed', 'id': 198, 'type': 'function', 'inputs': [
# {'name': 'speed', 'id': 199, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_joint_acc', 'id': 200, 'type': 'function', 'inputs': [
# {'name': 'acc', 'id': 201, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_command_mode', 'id': 202, 'type': 'function', 'inputs': [
# {'name': 'mode', 'id': 203, 'type': 'uint32', 'access': 'rw'}], 'outputs': []},
# {'name': 'tuning', 'type': 'object', 'members': [
# {'name': 'set_tuning_freq_amp', 'id': 204, 'type': 'function', 'inputs': [
# {'name': 'freq', 'id': 205, 'type': 'float', 'access': 'rw'},
# {'name': 'amp', 'id': 206, 'type': 'float', 'access': 'rw'}], 'outputs': []},
# {'name': 'set_tuning_flag', 'id': 207, 'type': 'function', 'inputs': [
# {'name': 'flag', 'id': 208, 'type': 'uint8', 'access': 'rw'}], 'outputs': []}]},
# {'name': 'eef_pose', 'type': 'object', 'members': [
# {'name': 'x', 'id': 209, 'type': 'float', 'access': 'r'},
# {'name': 'y', 'id': 210, 'type': 'float', 'access': 'r'},
# {'name': 'z', 'id': 211, 'type': 'float', 'access': 'r'},
# {'name': 'a', 'id': 212, 'type': 'float', 'access': 'r'},
# {'name': 'b', 'id': 213, 'type': 'float', 'access': 'r'},
# {'name': 'c', 'id': 214, 'type': 'float', 'access': 'r'},
# {'name': 'update_pose_6D', 'id': 215, 'type': 'function', 'inputs': [], 'outputs': []}]}]}]
# malformed member : unsupported codec json

# %% [markdown]
# ## RPC连上后,每一个层级都可以直接打印查看

# %%
teach_arm.robot
# Out:
# calibrate_home_offset()
# homing()
# resting()
# joint_1:
#   angle = 0.0 (float)
#   current = 0.0 (float)
#   velocity = 0.0 (float)
#   reboot()
#   erase_configs()
#   set_enable(enable: bool)
#   set_position(pos: float)
#   set_velocity(vel: float)
#   apply_home_offset()
#   set_dce_kp(vel: int)
#   set_dce_kv(vel: int)
#   set_dce_ki(vel: int)
#   set_dce_kd(vel: int)
#   update_angle()
# joint_2:
#   angle = 0.0 (float)
#   current = 0.0 (float)
#   velocity = 0.0 (float)
#   reboot()
#   erase_configs()
#   set_enable(enable: bool)
#   set_position(pos: float)
#   set_velocity(vel: float)
#   apply_home_offset()
#   set_dce_kp(vel: int)
#   set_dce_kv(vel: int)
#   set_dce_ki(vel: int)
#   set_dce_kd(vel: int)
#   update_angle()
# joint_3:
#   angle = -0.0004218749818392098 (float)
#   current = 0.0 (float)
#   velocity = 0.0 (float)
#   reboot()
#   erase_configs()
#   set_enable(enable: bool)
#   set_position(pos: float)
#   set_velocity(vel: float)
#   apply_home_offset()
#   set_dce_kp(vel: int)
#   set_dce_kv(vel: int)
#   set_dce_ki(vel: int)
#   set_dce_kd(vel: int)
#   update_angle()
# joint_4:
#   angle = -0.0 (float)
#   current = 0.0 (float)
#   velocity = 0.0 (float)
#   reboot()
#   erase_configs()
#   set_enable(enable: bool)
#   set_position(pos: float)
#   set_velocity(vel: float)
#   apply_home_offset()
#   set_dce_kp(vel: int)
#   set_dce_kv(vel: int)
#   set_dce_ki(vel: int)
#   set_dce_kd(vel: int)
#   update_angle()
# joint_5:
#   angle = -0.0 (float)
#   current = 0.0 (float)
#   velocity = 0.0 (float)
#   reboot()
#   erase_configs()
#   set_enable(enable: bool)
#   set_position(pos: float)
#   set_velocity(vel: float)
#   apply_home_offset()
#   set_dce_kp(vel: int)
#   set_dce_kv(vel: int)
#   set_dce_ki(vel: int)
#   set_dce_kd(vel: int)
#   update_angle()
# joint_6:
#   angle = 0.0004218749818392098 (float)
#   current = 0.0 (float)
#   velocity = 0.0 (float)
#   reboot()
#   erase_configs()
#   set_enable(enable: bool)
#   set_position(pos: float)
#   set_velocity(vel: float)
#   apply_home_offset()
#   set_dce_kp(vel: int)
#   set_dce_kv(vel: int)
#   set_dce_ki(vel: int)
#   set_dce_kd(vel: int)
#   update_angle()
# joint_all:
#   angle = -178.33360290527344 (float)
#   current = 0.0 (float)
#   velocity = 0.0 (float)
#   reboot()
#   erase_configs()
#   set_enable(enable: bool)
#   set_position(pos: float)
#   set_velocity(vel: float)
#   apply_home_offset()
#   set_dce_kp(vel: int)
#   set_dce_kv(vel: int)
#   set_dce_ki(vel: int)
#   set_dce_kd(vel: int)
#   update_angle()
# hand:
#   is_enabled = False (bool)
#   current_mode = 1 (int)
#   position = 0.0 (float)
#   velocity = 0.0 (float)
#   torque = 0.0 (float)
#   rotor_temp = 0.0 (float)
#   is_connected()
#   set_enable(enable: bool)
#   set_mode(mode: int)
#   read_mode()
#   set_zero()
#   control_mit(kp: float, kd: float, position: float, velocity: float, torque: float)
# reboot()
# set_enable(enable: bool)
# move_j(j1: float, j2: float, j3: float, j4: float, j5: float, j6: float)
# move_l(x: float, y: float, z: float, a: float, b: float, c: float)
# set_joint_speed(speed: float)
# set_joint_acc(acc: float)
# set_command_mode(mode: int)
# tuning:
#   set_tuning_freq_amp(freq: float, amp: float)
#   set_tuning_flag(flag: int)
# eef_pose:
#   x = 0.0 (float)
#   y = 0.0 (float)
#   z = 0.0 (float)
#   a = 0.0 (float)
#   b = 0.0 (float)
#   c = 0.0 (float)
#   update_pose_6D()

# %%
teach_arm.robot.joint_3
# Out:
# angle = -0.0004218749818392098 (float)
# current = 0.0 (float)
# velocity = 0.0 (float)
# reboot()
# erase_configs()
# set_enable(enable: bool)
# set_position(pos: float)
# set_velocity(vel: float)
# apply_home_offset()
# set_dce_kp(vel: int)
# set_dce_kv(vel: int)
# set_dce_ki(vel: int)
# set_dce_kd(vel: int)
# update_angle()

# %%
teach_arm.robot.hand
# Out:
# is_enabled = False (bool)
# current_mode = 1 (int)
# position = 0.0 (float)
# velocity = 0.0 (float)
# torque = 0.0 (float)
# rotor_temp = 0.0 (float)
# is_connected()
# set_enable(enable: bool)
# set_mode(mode: int)
# read_mode()
# set_zero()
# control_mit(kp: float, kd: float, position: float, velocity: float, torque: float)

# %% [markdown]
# ## 接着让我们来测试一些功能

# %% [markdown]
# ### 机械臂MoveJ

# %%
# Reset Pose
teach_arm.robot.set_enable(True)
teach_arm.robot.move_j(0, -73, 180, 0, 0, 0)

# %%
# Home Pose
teach_arm.robot.set_enable(True)
teach_arm.robot.move_j(0, 0, 90, 0, 0, 0)
# Out:
# True

# %%
# Work Pose
teach_arm.robot.set_enable(True)
teach_arm.robot.move_j(0, 0, 90, 0, 55, 0)
# Out:
# True

# %% [markdown]
# ### 获取所有关节角度(获取到的这个角度是电机的关节机械角, 和运动学模型角度之间存在一个固定的offset)

# %%
joint_offset = np.array([0,-73,180,0,0,0])
all_joint_angles = teach_arm.robot.joint_1.angle, teach_arm.robot.joint_2.angle, teach_arm.robot.joint_3.angle, teach_arm.robot.joint_4.angle, teach_arm.robot.joint_5.angle, teach_arm.robot.joint_6.angle
all_joint_angles = np.round(np.array(all_joint_angles))
all_joint_angles = all_joint_angles + joint_offset
all_joint_angles
# Out:
# array([ 0.,  0., 90.,  0., 55.,  0.])

# %%
def get_all_joint_angles(arm_interface):
    joint_offset = np.array([0,-73,180,0,0,0])
    all_joint_angles = arm_interface.robot.joint_1.angle, arm_interface.robot.joint_2.angle, arm_interface.robot.joint_3.angle, arm_interface.robot.joint_4.angle, arm_interface.robot.joint_5.angle, arm_interface.robot.joint_6.angle
    all_joint_angles = np.round(np.array(all_joint_angles))
    all_joint_angles = all_joint_angles + joint_offset
    return all_joint_angles

# %% [markdown]
# ### 获取当前末端位姿(旋转使用ZYX欧拉角序列(也称为RPY - Roll, Pitch, Yaw))

# %%
def get_current_pose():
    teach_arm.robot.eef_pose.update_pose_6D()
    x,y,z,rz,ry,rx = teach_arm.robot.eef_pose.x, teach_arm.robot.eef_pose.y, teach_arm.robot.eef_pose.z, teach_arm.robot.eef_pose.a, teach_arm.robot.eef_pose.b, teach_arm.robot.eef_pose.c
    current_pose = np.array([x,y,z,rz,ry,rx])
    return current_pose

current_pose = get_current_pose()
current_pose
# Out:
# array([195.29989624,   0.        , 262.65988159, 180.        ,
#         35.00170898, 180.        ])

# %% [markdown]
# ### 机械臂MoveL(直接控制末端在笛卡尔空间运动, 输入单位是mm)

# %%
# 沿着x轴方向移动10mm
teach_arm.robot.move_l(current_pose[0]+10, current_pose[1], current_pose[2], current_pose[3], current_pose[4], current_pose[5])
current_pose = get_current_pose()
current_pose

# %%
# 沿着z轴方向移动10mm
teach_arm.robot.move_l(current_pose[0], current_pose[1], current_pose[2]-10, current_pose[3], current_pose[4], current_pose[5])
current_pose = get_current_pose()
current_pose

# %% [markdown]
# ### 归巢

# %%
teach_arm.robot.resting()

# %% [markdown]
# ### 复位回到home pose

# %%
teach_arm.robot.joint_3

# %%
teach_arm.robot.set_enable(True)

# %%
teach_arm.robot.move_j(0, -73, 180, 0, 0, 0)

# %%
teach_arm.robot.move_j(0, 0, 90, 0, 0, 0)

# %%
teach_arm.robot.joint_3

# %% [markdown]
# ### 示教臂的夹爪实时位置读取

# %%
## 让夹爪电机进入零力矩状态
teach_arm.robot.hand.set_mode(0)
teach_arm.robot.hand.set_torque(0)

# %%
teach_arm.robot.set_enable(False)
## 拖动夹爪然后查看角度变化
rate = 2  # 50Hz
def get_current_pose():
    teach_arm.robot.eef_pose.update_pose_6D()
    x,y,z,rz,ry,rx = teach_arm.robot.eef_pose.x, teach_arm.robot.eef_pose.y, teach_arm.robot.eef_pose.z, teach_arm.robot.eef_pose.a, teach_arm.robot.eef_pose.b, teach_arm.robot.eef_pose.c
    current_pose = np.array([x,y,z,rz,ry,rx])
    return current_pose


import time
while True:
    start_time = time.time()
    current_pose = get_current_pose()
    print(current_pose)
    time.sleep(1/rate)
    print(teach_arm.robot.hand.angle)

# %%
teach_arm.robot.set_enable(False)
import time
rate = 0.1  # 10Hz
## 让夹爪电机进入零力矩状态
teach_arm.robot.hand.set_mode(0)
teach_arm.robot.hand.set_torque(0)
while True:
    start_time = time.time()
    joint1_angle = teach_arm.robot.joint_1.angle
    joint2_angle = teach_arm.robot.joint_2.angle
    joint3_angle = teach_arm.robot.joint_3.angle
    joint4_angle = teach_arm.robot.joint_4.angle
    joint5_angle = teach_arm.robot.joint_5.angle
    joint6_angle = teach_arm.robot.joint_6.angle
    # print(f"Current leader Joints: {joint1_angle}, {joint2_angle}, {joint3_angle}, {joint4_angle}, {joint5_angle}, {joint6_angle}")
    all_joint_angles = np.array([joint1_angle, joint2_angle, joint3_angle, joint4_angle, joint5_angle, joint6_angle]) + joint_offset
    all_joint_angles = np.round(all_joint_angles, 0)
    # print("Current gripper: ",teach_arm.robot.hand.angle)
    # joint1_qpos = teach_arm.robot.joint_1.position
    joint1_qvel = teach_arm.robot.joint_1.velocity
    print( "qvel: ", joint1_qvel)
    joint2_qvel = teach_arm.robot.joint_2.velocity
    joint3_qvel = teach_arm.robot.joint_3.velocity
    joint4_qvel = teach_arm.robot.joint_4.velocity
    joint5_qvel = teach_arm.robot.joint_5.velocity
    joint6_qvel = teach_arm.robot.joint_6.velocity
    print( "qvel: ", joint2_qvel, joint3_qvel, joint4_qvel, joint5_qvel, joint6_qvel)
    # follow_arm.robot.move_j(all_joint_angles[0], all_joint_angles[1], all_joint_angles[2], all_joint_angles[3], all_joint_angles[4], all_joint_angles[5])
    # follow_arm.robot.hand.set_angle(teach_arm.robot.hand.angle - teach_hand_init_angle + follow_hand_init_angle)
    # print(f"Current follower Joints (state): {all_joint_angles}")
    # collector.collect_step(
    # teach_joints=np.array([joint1_angle, joint2_angle, joint3_angle, 
    #                         joint4_angle, joint5_angle, joint6_angle]),
    # follow_joints=all_joint_angles,
    # teach_gripper=teach_arm.robot.hand.angle,
    # follow_gripper=follow_arm.robot.hand.angle
    # )
    # Sleep precisely to maintain 10Hz
    elapsed = time.time() - start_time
    if elapsed < rate:
        time.sleep(rate - elapsed)
    
    # Calculate and print actual loop frequency
    loop_time = time.time() - start_time
    actual_freq = 1.0 / loop_time if loop_time > 0 else 0
    print(f"Current loop frequency: {actual_freq:.2f} Hz")

# %% [markdown]
# ### 示教臂的夹爪实时力矩读取(即将支持,硬件施工中)

# %% [markdown]
# ### Follow Arm相机测试

# %%
import cv2
mjpg_streamer_url = "http://192.168.65.110:8080/?action=stream"
cap = cv2.VideoCapture(mjpg_streamer_url)
while True:
    ret, frame = cap.read()
    cv2.imshow("frame", frame)
    cv2.waitKey(1)
cv2.destroyAllWindows()

# %% [markdown]
# # 校准机械臂初始状态

# %%
from __future__ import print_function
import fibre
logger = fibre.utils.Logger(verbose=True)
SN = "396636713233"
teach_arm = fibre.find_any(serial_number=SN, logger=logger)

# %%
teach_arm.robot.resting()

# %%
import numpy as np
def get_current_pose():
    teach_arm.robot.eef_pose.update_pose_6D()
    x,y,z,rz,ry,rx = teach_arm.robot.eef_pose.x, teach_arm.robot.eef_pose.y, teach_arm.robot.eef_pose.z, teach_arm.robot.eef_pose.a, teach_arm.robot.eef_pose.b, teach_arm.robot.eef_pose.c
    current_pose = np.array([x,y,z,rz,ry,rx])
    return current_pose

current_pose = get_current_pose()
current_pose

# %%
teach_arm.robot.set_enable(True)
teach_arm.robot.move_l(current_pose[0], 0.1, current_pose[2], current_pose[3], current_pose[4], current_pose[5])
current_pose = get_current_pose()
current_pose

# %%
# Enable motor but disable circle udpate
teach_arm.robot.joint_all.set_enable(True)
teach_arm.robot.set_enable(False)

# %% [markdown]
# ## 先手动把机械臂挪成L姿态, 然后运行以下代码

# %%
teach_arm.robot.joint_1.apply_home_offset()
teach_arm.robot.joint_2.apply_home_offset()
teach_arm.robot.joint_3.apply_home_offset()
teach_arm.robot.joint_4.apply_home_offset()
teach_arm.robot.joint_5.apply_home_offset()
teach_arm.robot.joint_6.apply_home_offset()

# %% [markdown]
# ## 再手动把机械臂挪回休息状态, 然后运行以下代码

# %%
teach_arm.robot.joint_1.apply_home_offset()
teach_arm.robot.joint_2.apply_home_offset()
teach_arm.robot.joint_3.apply_home_offset()
teach_arm.robot.joint_4.apply_home_offset()
teach_arm.robot.joint_5.apply_home_offset()
teach_arm.robot.joint_6.apply_home_offset()

# %%
teach_arm.robot.set_enable(True)
teach_arm.robot.move_j(0, 0, 90, 0, 55, 0)

# %%
teach_arm.robot.set_enable(True)
teach_arm.robot.move_j(-17.21704864501953, 41.4782829284668, 23.368927001953125, 0.0007031249697320163, 70.50114440917969, 2.599015235900879)

# %%
import fibre
import numpy as np

from __future__ import print_function
logger = fibre.utils.Logger(verbose=True)
teach_arm = fibre.find_any(serial_number="208C31875253", logger=logger)
follow_arm = fibre.find_any(serial_number="396636713233", logger=logger)

# %%
teach_arm.robot.set_enable(True)
teach_arm.robot.hand.set_mode(0)

# %%
teach_arm.robot.hand.set_angle(27)

# %%
print(teach_arm.robot.hand.angle - follow_arm.robot.hand.angle)

# %%
teach_arm.robot.hand.set_current_limit(-0.1)

# %%
teach_arm.robot.hand.set_mode(0)
teach_arm.robot.hand.set_torque(0)

# %%
teach_arm.robot.hand.get_current_limit()

# %%
follow_arm.robot.hand.get_current_limit()

# %%
teach_arm.robot.hand.set_mode(2)
teach_arm.robot.set_enable(True)
teach_arm.robot.hand.set_angle(27)

# %%
teach_arm.robot.hand.angle

# %%
follow_arm = fibre.find_any(serial_number="396636713233", logger=logger)

# %%
print(follow_arm.robot)

# %%
follow_arm.robot.homing()

# %%
follow_arm.robot.move_j(10,10,92,5,10,10)

# %%
follow_arm.robot.set_enable(True)

# %%
from __future__ import print_function
import fibre
logger = fibre.utils.Logger(verbose=True)
SN = "396636713233"
teach_arm = fibre.find_any(serial_number=SN, logger=logger)
teach_arm.robot.resting()

# %%
teach_arm.robot.set_enable(True)
teach_arm.robot.move_j(       -16.527421951293945,
      55.114776611328125,
      26.215545654296875,
      0.0007031249697320163,
      69.51187896728516,
      3.933046817779541)

# %%
teach_arm.robot.set_enable(True)
teach_arm.robot.move_j(       -16.49370574951172,
      49.11359405517578,
      26.32851791381836,
      3.4315928587602684e-06,
      71.90644836425781,
      3.8402748107910156)
